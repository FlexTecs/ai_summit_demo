# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FlexTecs/ai_summit_demo/blob/main/claude_web_demo.ipynb)
#
# # FlexTecs Claude Code agent demo (Team B)
#
# We will be interacting with the FlexTecs AI summit data, but rather than using the terminal Claude Code agent, your team will use the standard web "chat" interface ([claude.ai](https://claude.ai)).
#
# The first step is to navigate to `File` in the upper left hand corner and select `Save a copy in Drive` so that any edits your team makes will be reflected in your version of the notebook.

# %% [markdown]
# ## Activity: Exploring Amazon Pricing Data
#
# 1. Navigate to [claude.ai](https://claude.ai).
# 2. Tell it to "navigate to the repo https://github.com/octaprice/ecommerce-product-dataset.git"
# 3. A subset of data is also extracted and hosted at this link for the summit: https://github.com/FlexTecs/ai_summit_demo/tree/main/data
#
# Suggested prompts:
# * Explore the amazon bestsellers dataset. Then summarize what is in it.
# * Explore the amazon bird seed dataset; then tell me what is in it.
# * Analyze pricing anomalies across the 3 different amazon bird seed data snapshots.
# * Write me a C# script to extract the most recent pricing data from the bestsellers list.
#
# ## Discussion prompts
#
# 1. What similarities or differences do you notice in outputs across the different types of prompts?
# 2. What techniques are you using to manage "context" and port code back and forth?
